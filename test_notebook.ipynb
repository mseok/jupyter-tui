# %% [markdown]
# # Test Notebook
#
# This is a test notebook for Jupyter TUI.

# %%
# Simple arithmetic
2 + 2

# %%
# Print statement
print("Hello from Jupyter TUI!")
print("This is a multi-line output")

# %%
# List comprehension
[x**2 for x in range(10)]
